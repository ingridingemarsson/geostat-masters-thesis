# %%
import xarray as xr
import pandas as pd
import os
import datetime

# %%
f = open('../path_to_data.txt', "r")
path_to_dataset = os.path.join(f.readline().rstrip("\n"))
f.close()

# %%
he = xr.open_dataset(os.path.join(path_to_dataset,'HE','HE_at_gauges_hour.nc'))

# %%
he
# Out:
# <xarray.Dataset>
# Dimensions:    (location: 609, time: 738)
# Coordinates:
#   * time       (time) datetime64[ns] 2020-12-01T01:00:00 ... 2020-12-31T18:00:00
#   * location   (location) int64 0 1 2 3 4 5 6 7 ... 602 603 604 605 606 607 608
# Data variables:
#     HE_precip  (time, location) float64 ...

# %%
regions = pd.read_pickle(os.path.join(path_to_dataset,'real_rain_gauge_data','regions.pckl'))

# %%
j = regions.index[regions.region == 'N'].values

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-4680c375e4aa> in <module>
# ----> 1 he.isel[j]
#
# TypeError: 'method' object is not subscriptable
